# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.5.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/mingdongfan/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2018.11.29         |        py37_1000         145 KB  conda-forge
#     geopy-1.18.1               |             py_0          51 KB  conda-forge
#     pyhamcrest-1.9.0           |             py_2          23 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     twisted-18.9.0             |   py37h470a237_0         4.9 MB  conda-forge
#     conda-4.5.12               |        py37_1000         652 KB  conda-forge
#     ca-certificates-2018.11.29 |       ha4d7672_0         143 KB  conda-forge
#     openssl-1.0.2p             |       h470a237_1         2.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0             conda-forge
#     geopy:           1.18.1-py_0           conda-forge
#     pyhamcrest:      1.9.0-py_2            conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.03.07-0                      --> 2018.11.29-ha4d7672_0 conda-forge
#     certifi:         2018.8.24-py37_1                  --> 2018.11.29-py37_1000  conda-forge
#     conda:           4.5.11-py37_0                     --> 4.5.12-py37_1000      conda-forge
#     openssl:         1.0.2p-h1de35cc_0                 --> 1.0.2p-h470a237_1     conda-forge
#     twisted:         18.7.0-py37h1de35cc_1             --> 18.9.0-py37h470a237_0 conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2018.11.29   | 145 KB    | ##################################### | 100%
# geopy-1.18.1         | 51 KB     | ##################################### | 100%
# pyhamcrest-1.9.0     | 23 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# twisted-18.9.0       | 4.9 MB    | ##################################### | 100%
# conda-4.5.12         | 652 KB    | ##################################### | 100%
# ca-certificates-2018 | 143 KB    | ##################################### | 100%
# openssl-1.0.2p       | 2.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/mingdongfan/anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mkl_fft-1.0.6              |   py37h27c97d8_0         182 KB
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     mkl-2019.1                 |              144       154.4 MB
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-0.23.4              |   py37hf8a1672_0        10.2 MB  conda-forge
#     altair-2.3.0               |        py37_1001         491 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     mkl_random-1.0.2           |   py37h27c97d8_0         358 KB
#     numpy-base-1.15.4          |   py37h6575580_0         4.1 MB
#     numpy-1.15.4               |   py37hacdab7b_0          47 KB
#     ------------------------------------------------------------
#                                            Total:       169.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:     2.3.0-py37_1001       conda-forge
#     branca:     0.3.1-py_0            conda-forge
#     folium:     0.5.0-py_0            conda-forge
#     vincent:    0.4.4-py_1            conda-forge
#
# The following packages will be UPDATED:
#
#     mkl:        2019.0-118                        --> 2019.1-144
#     mkl_fft:    1.0.4-py37h5d10147_1              --> 1.0.6-py37h27c97d8_0
#     mkl_random: 1.0.1-py37h5d10147_1              --> 1.0.2-py37h27c97d8_0
#     numpy:      1.15.1-py37h6a91979_0             --> 1.15.4-py37hacdab7b_0
#     numpy-base: 1.15.1-py37h8a80b8c_0             --> 1.15.4-py37h6575580_0
#     pandas:     0.23.4-py37h6440ff4_0             --> 0.23.4-py37hf8a1672_0 conda-forge
#
#
# Downloading and Extracting Packages
# mkl_fft-1.0.6        | 182 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# mkl-2019.1           | 154.4 MB  | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# pandas-0.23.4        | 10.2 MB   | ##################################### | 100%
# altair-2.3.0         | 491 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# mkl_random-1.0.2     | 358 KB    | ##################################### | 100%
# numpy-base-1.15.4    | 4.1 MB    | ##################################### | 100%
# numpy-1.15.4         | 47 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 1. Toronto Neighbourhoods

# %%
# Toronto Neighbourhoods Data
G3 = pd.read_csv('G3.csv')
G3 = G3.drop('Unnamed: 0', axis = 1)
G3.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ### Toronto Neighbourhoods Map

# %%
# create map of Manhattan using latitude and longitude values
latitude = 43.6532
longitude = -79.3832
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(G3['Latitude'], G3['Longitude'], G3['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'QS44NWUNPK5JSK4G5XJFUGL1VJNCDP2MGBQ5NDOVDPJAANHK' # your Foursquare ID
CLIENT_SECRET = 'XKVRUXX4RTZZKGGWHT03AOHKJ3EDI4XMFH5WZYCNL5FSJOY1' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# ## 2. Venues Near Selected Neighbourhoods

# %% [markdown]
# ### Select Neighbourhoods with string 'Toronto'

# %%
G4 = G3[G3['Neighbourhood'].str.contains('Toronto')]
G4
# Out:
#    Postcode           Borough  \
# 30      M3K        North York
# 40      M4J         East York
# 46      M4R   Central Toronto
# 59      M5J  Downtown Toronto
# 60      M5K  Downtown Toronto
# 66      M5S  Downtown Toronto
# 88      M8V         Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 30                        CFB Toronto, Downsview East  43.737473 -79.464763
# 40                                       East Toronto  43.685347 -79.338106
# 46                                 North Toronto West  43.715383 -79.405678
# 59  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 60           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 66                     Harbord, University of Toronto  43.662696 -79.400049
# 88       Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321

# %% [markdown]
# ### Extract Neighbourhood Venues Using Foursquare

# %%
LIMIT = 100
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=G4['Neighbourhood'], latitudes=G4['Latitude'], longitudes=G4['Longitude'])
# Out:
# CFB Toronto, Downsview East
# East Toronto
# North Toronto West
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Harbord, University of Toronto
# Humber Bay Shores, Mimico South, New Toronto

# %% [markdown]
# ### Number of Venues

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (274, 7)
#                   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  CFB Toronto, Downsview East              43.737473              -79.464763
# 1  CFB Toronto, Downsview East              43.737473              -79.464763
# 2  CFB Toronto, Downsview East              43.737473              -79.464763
# 3                 East Toronto              43.685347              -79.338106
# 4                 East Toronto              43.685347              -79.338106
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 0  Toronto Downsview Airport (YZD)       43.738883       -79.470111
# 1         Ttc Bus #120 - Plewes Rd       43.734898       -79.464221
# 2                    Ancaster Park       43.733724       -79.465528
# 3                         The Path       43.683923       -79.335007
# 4               Sammon Convenience       43.686951       -79.335007
#
#       Venue Category
# 0            Airport
# 1           Bus Stop
# 2               Park
# 3               Park
# 4  Convenience Store

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# CFB Toronto, Downsview East                                            3
# Design Exchange, Toronto Dominion Centre                             100
# East Toronto                                                           3
# Harbord, University of Toronto                                        33
# Harbourfront East, Toronto Islands, Union Station                    100
# Humber Bay Shores, Mimico South, New Toronto                          16
# North Toronto West                                                    19
#
#                                                    Neighborhood Longitude  \
# Neighborhood
# CFB Toronto, Downsview East                                             3
# Design Exchange, Toronto Dominion Centre                              100
# East Toronto                                                            3
# Harbord, University of Toronto                                         33
# Harbourfront East, Toronto Islands, Union Station                     100
# Humber Bay Shores, Mimico South, New Toronto                           16
# North Toronto West                                                     19
#
#                                                    Venue  Venue Latitude  \
# Neighborhood
# CFB Toronto, Downsview East                            3               3
# Design Exchange, Toronto Dominion Centre             100             100
# East Toronto                                           3               3
# Harbord, University of Toronto                        33              33
# Harbourfront East, Toronto Islands, Union Station    100             100
# Humber Bay Shores, Mimico South, New Toronto          16              16
# North Toronto West                                    19              19
#
#                                                    Venue Longitude  \
# Neighborhood
# CFB Toronto, Downsview East                                      3
# Design Exchange, Toronto Dominion Centre                       100
# East Toronto                                                     3
# Harbord, University of Toronto                                  33
# Harbourfront East, Toronto Islands, Union Station              100
# Humber Bay Shores, Mimico South, New Toronto                    16
# North Toronto West                                              19
#
#                                                    Venue Category
# Neighborhood
# CFB Toronto, Downsview East                                     3
# Design Exchange, Toronto Dominion Centre                      100
# East Toronto                                                    3
# Harbord, University of Toronto                                 33
# Harbourfront East, Toronto Islands, Union Station             100
# Humber Bay Shores, Mimico South, New Toronto                   16
# North Toronto West                                             19

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 98 uniques categories.

# %% [markdown]
# ## 3. Analyze Each Neighborhood

# %% [markdown]
# ### Frequency of Venues Grouped by neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                         Neighborhood  Yoga Studio   Airport  \
# 0                        CFB Toronto, Downsview East     0.000000  0.333333
# 1           Design Exchange, Toronto Dominion Centre     0.000000  0.000000
# 2                                       East Toronto     0.000000  0.000000
# 3                     Harbord, University of Toronto     0.000000  0.000000
# 4  Harbourfront East, Toronto Islands, Union Station     0.000000  0.000000
# 5       Humber Bay Shores, Mimico South, New Toronto     0.000000  0.000000
# 6                                 North Toronto West     0.052632  0.000000
#
#    American Restaurant  Aquarium  Art Gallery  Asian Restaurant    Bakery  \
# 0               0.0000      0.00         0.00              0.00  0.000000
# 1               0.0400      0.00         0.01              0.01  0.010000
# 2               0.0000      0.00         0.00              0.00  0.000000
# 3               0.0000      0.00         0.00              0.00  0.060606
# 4               0.0000      0.05         0.01              0.00  0.030000
# 5               0.0625      0.00         0.00              0.00  0.062500
# 6               0.0000      0.00         0.00              0.00  0.000000
#
#    Bank       Bar  Baseball Stadium  Basketball Stadium  Beer Bar  Beer Store  \
# 0  0.00  0.000000              0.00                0.00  0.000000    0.000000
# 1  0.00  0.020000              0.00                0.01  0.010000    0.000000
# 2  0.00  0.000000              0.00                0.00  0.000000    0.000000
# 3  0.00  0.060606              0.00                0.00  0.030303    0.030303
# 4  0.01  0.020000              0.01                0.01  0.000000    0.000000
# 5  0.00  0.000000              0.00                0.00  0.000000    0.000000
# 6  0.00  0.000000              0.00                0.00  0.000000    0.000000
#
#    Bistro  Bookstore  Brewery  Bubble Tea Shop  Burger Joint  Bus Stop  \
# 0    0.00   0.000000     0.00             0.00          0.00  0.333333
# 1    0.00   0.010000     0.00             0.00          0.02  0.000000
# 2    0.00   0.000000     0.00             0.00          0.00  0.000000
# 3    0.00   0.060606     0.00             0.00          0.00  0.000000
# 4    0.01   0.000000     0.03             0.01          0.00  0.000000
# 5    0.00   0.000000     0.00             0.00          0.00  0.000000
# 6    0.00   0.000000     0.00             0.00          0.00  0.000000
#
#        Café  Chinese Restaurant  Clothing Store  Coffee Shop  \
# 0  0.000000            0.000000        0.000000     0.000000
# 1  0.090000            0.000000        0.000000     0.140000
# 2  0.000000            0.000000        0.000000     0.333333
# 3  0.121212            0.030303        0.000000     0.060606
# 4  0.040000            0.010000        0.000000     0.140000
# 5  0.062500            0.000000        0.000000     0.125000
# 6  0.000000            0.052632        0.105263     0.105263
#
#    College Arts Building  College Gym  Comfort Food Restaurant  Concert Hall  \
# 0               0.000000     0.000000                 0.000000          0.00
# 1               0.000000     0.000000                 0.000000          0.02
# 2               0.000000     0.000000                 0.000000          0.00
# 3               0.030303     0.030303                 0.030303          0.00
# 4               0.000000     0.000000                 0.000000          0.00
# 4             0.00  0.010000           0.02                           0.01
# 5             0.00  0.000000           0.00                           0.00
# 6             0.00  0.000000           0.00                           0.00
#
#    Video Game Store  Wine Bar
# 0          0.000000      0.00
# 1          0.000000      0.01
# 2          0.000000      0.00
# 3          0.030303      0.00
# 4          0.000000      0.01
# 5          0.000000      0.00
# 6          0.000000      0.00

# %% [markdown]
# ### Top 10 venues for each neighborhood

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']
# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                        CFB Toronto, Downsview East               Airport
# 1           Design Exchange, Toronto Dominion Centre           Coffee Shop
# 2                                       East Toronto           Coffee Shop
# 3                     Harbord, University of Toronto                  Café
# 4  Harbourfront East, Toronto Islands, Union Station           Coffee Shop
# 5       Humber Bay Shores, Mimico South, New Toronto           Coffee Shop
# 6                                 North Toronto West   Sporting Goods Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Park              Bus Stop              Wine Bar
# 1                  Café                 Hotel            Restaurant
# 2     Convenience Store                  Park              Wine Bar
# 3   Japanese Restaurant           Coffee Shop                Bakery
# 4              Aquarium                 Hotel           Pizza Place
# 5           Flower Shop                   Gym            Restaurant
# 6           Coffee Shop        Clothing Store           Yoga Studio
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Flower Shop     Convenience Store          Dance Studio
# 1   American Restaurant             Gastropub         Deli / Bodega
# 2     Fish & Chips Shop          Concert Hall          Dance Studio
# 3                   Bar            Restaurant             Bookstore
# 4                  Café            Restaurant                Bakery
# 5                  Café        Sandwich Place  Fast Food Restaurant
# 6                   Spa  Fast Food Restaurant    Mexican Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Deli / Bodega          Dessert Shop                  Diner
# 1                   Gym                   Bar             Steakhouse
# 2         Deli / Bodega          Dessert Shop                  Diner
# 3    Italian Restaurant             Nightclub           Noodle House
# 4        Scenic Lookout    Italian Restaurant                Brewery
# 5              Pharmacy     Fish & Chips Shop           Liquor Store
# 6                 Diner          Dessert Shop                   Park

# %% [markdown]
# ## 4. Cluster Neighborhoods

# %% [markdown]
# ### K-means Clustering

# %%
# set number of clusters
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)
# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 0, 2, 0, 0, 4, 3], dtype=int32)

# %%
toronto_merged = G4
# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_
# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')
toronto_merged.head() # check the last columns!
# Out:
# /Users/mingdongfan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Postcode           Borough  \
# 30      M3K        North York
# 40      M4J         East York
# 46      M4R   Central Toronto
# 59      M5J  Downtown Toronto
# 60      M5K  Downtown Toronto
#
#                                         Neighbourhood   Latitude  Longitude  \
# 30                        CFB Toronto, Downsview East  43.737473 -79.464763
# 40                                       East Toronto  43.685347 -79.338106
# 46                                 North Toronto West  43.715383 -79.405678
# 59  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 60           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 30               1               Airport                  Park
# 40               0           Coffee Shop     Convenience Store
# 46               2   Sporting Goods Shop           Coffee Shop
# 59               0           Coffee Shop              Aquarium
# 60               0           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 30              Bus Stop              Wine Bar           Flower Shop
# 40                  Park              Wine Bar     Fish & Chips Shop
# 46        Clothing Store           Yoga Studio                   Spa
# 59                 Hotel           Pizza Place                  Café
# 60                 Hotel            Restaurant   American Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 30     Convenience Store          Dance Studio         Deli / Bodega
# 40          Concert Hall          Dance Studio         Deli / Bodega
# 46  Fast Food Restaurant    Mexican Restaurant                 Diner
# 59            Restaurant                Bakery        Scenic Lookout
# 60             Gastropub         Deli / Bodega                   Gym
#
#    9th Most Common Venue 10th Most Common Venue
# 30          Dessert Shop                  Diner
# 40          Dessert Shop                  Diner
# 46          Dessert Shop                   Park
# 59    Italian Restaurant                Brewery
# 60                   Bar             Steakhouse

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
